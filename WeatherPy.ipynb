# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 584

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=metric'

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url)
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | vorkuta
# Processing Record 3 of Set 1 | sitka
# Processing Record 4 of Set 1 | adamstown
# Processing Record 5 of Set 1 | bilibino
# Processing Record 6 of Set 1 | sao joao da barra
# Processing Record 7 of Set 1 | nantucket
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | shache
# Processing Record 10 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 11 of Set 1 | waitangi
# Processing Record 12 of Set 1 | mahibadhoo
# Processing Record 13 of Set 1 | jayapura
# Processing Record 14 of Set 1 | greymouth
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | rongelap
# Processing Record 17 of Set 1 | qaqortoq
# Processing Record 18 of Set 1 | haiku-pauwela
# Processing Record 19 of Set 1 | port mathurin
# Processing Record 20 of Set 1 | port-aux-francais
# Processing Record 21 of Set 1 | bodo
# Processing Record 22 of Set 1 | mitu
# Processing Record 23 of Set 1 | kerikeri
# Processing Record 24 of Set 1 | tiksi
# Processing Record 25 of Set 1 | aasiaat
# Processing Record 26 of Set 1 | crane
# Processing Record 27 of Set 1 | blackmans bay
# Processing Record 28 of Set 1 | forster
# Processing Record 29 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 30 of Set 1 | olonkinbyen
# Processing Record 31 of Set 1 | whitehorse
# Processing Record 32 of Set 1 | aykhal
# Processing Record 33 of Set 1 | maxixe
# Processing Record 34 of Set 1 | west island
# Processing Record 35 of Set 1 | waingapu
# Processing Record 36 of Set 1 | mana
# Processing Record 37 of Set 1 | edinburgh of the seven seas
# Processing Record 38 of Set 1 | puerto natales
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | ilulissat
# Processing Record 41 of Set 1 | chernyshevskiy
# Processing Record 42 of Set 1 | lembar
# City not found. Skipping...
# Processing Record 43 of Set 1 | nizhniy odes
# Processing Record 44 of Set 1 | san patricio
# Processing Record 45 of Set 1 | colonia
# Processing Record 46 of Set 1 | belmonte
# Processing Record 47 of Set 1 | mugumu
# Processing Record 48 of Set 1 | st. john's
# Processing Record 49 of Set 1 | island harbour
# Processing Record 50 of Set 1 | tiruchchendur
# Processing Record 0 of Set 2 | yellowknife
# Processing Record 1 of Set 2 | temnikov
# Processing Record 2 of Set 2 | morehead city
# Processing Record 3 of Set 2 | grytviken
# Processing Record 4 of Set 2 | masterton
# Processing Record 5 of Set 2 | wailua homesteads
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | tambovka
# Processing Record 8 of Set 2 | stephenville
# Processing Record 9 of Set 2 | kultali
# City not found. Skipping...
# Processing Record 10 of Set 2 | tazovsky
# Processing Record 11 of Set 2 | kristiansund
# Processing Record 12 of Set 2 | savantvadi
# Processing Record 13 of Set 2 | tshabong
# Processing Record 14 of Set 2 | nyala
# Processing Record 15 of Set 2 | robore
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | happy valley-goose bay
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | levuka
# Processing Record 20 of Set 2 | kavaratti
# Processing Record 21 of Set 2 | dudinka
# Processing Record 22 of Set 2 | pueblo nuevo
# Processing Record 23 of Set 2 | ulaangom
# Processing Record 24 of Set 2 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 25 of Set 2 | cargados carajos
# City not found. Skipping...
# Processing Record 26 of Set 2 | kodiak
# Processing Record 27 of Set 2 | yemetsk
# Processing Record 28 of Set 2 | wajir
# Processing Record 29 of Set 2 | ushuaia
# Processing Record 30 of Set 2 | hamilton
# Processing Record 31 of Set 2 | savannakhet
# Processing Record 32 of Set 2 | carutapera
# Processing Record 33 of Set 2 | clarksburg
# Processing Record 34 of Set 2 | port elizabeth
# Processing Record 35 of Set 2 | margaret river
# Processing Record 36 of Set 2 | albany
# Processing Record 37 of Set 2 | lihue
# Processing Record 38 of Set 2 | fuvahmulah
# City not found. Skipping...
# Processing Record 39 of Set 2 | ladismith
# City not found. Skipping...
# Processing Record 40 of Set 2 | alotau
# Processing Record 41 of Set 2 | malanje
# Processing Record 42 of Set 2 | yuli
# Processing Record 43 of Set 2 | asmar
# Processing Record 44 of Set 2 | namtsy
# Processing Record 45 of Set 2 | papatowai
# Processing Record 46 of Set 2 | okha
# Processing Record 47 of Set 2 | sao felix do xingu
# Processing Record 48 of Set 2 | longyearbyen
# Processing Record 49 of Set 2 | kurchatov
# Processing Record 0 of Set 3 | talnakh
# Processing Record 1 of Set 3 | inza
# Processing Record 2 of Set 3 | invercargill
# Processing Record 3 of Set 3 | khovd
# Processing Record 4 of Set 3 | hithadhoo
# Processing Record 5 of Set 3 | olgii
# City not found. Skipping...
# Processing Record 6 of Set 3 | bethel
# Processing Record 7 of Set 3 | maragogi
# Processing Record 8 of Set 3 | nikopol
# Processing Record 9 of Set 3 | hirara
# Processing Record 10 of Set 3 | guerrero negro
# Processing Record 11 of Set 3 | lata
# Processing Record 12 of Set 3 | clearwater
# Processing Record 13 of Set 3 | la passe
# Processing Record 14 of Set 3 | bereznik
# Processing Record 15 of Set 3 | atafu village
# Processing Record 16 of Set 3 | anadyr
# Processing Record 17 of Set 3 | polygyros
# Processing Record 18 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 19 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 20 of Set 3 | nguigmi
# Processing Record 21 of Set 3 | progreso
# Processing Record 22 of Set 3 | mount isa
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | talakan
# Processing Record 25 of Set 3 | ad dilam
# Processing Record 26 of Set 3 | isafjordur
# Processing Record 27 of Set 3 | ruelle-sur-touvre
# Processing Record 28 of Set 3 | taroa
# Processing Record 29 of Set 3 | jacmel
# Processing Record 30 of Set 3 | dzilam gonzalez
# Processing Record 31 of Set 3 | hawaiian paradise park
# Processing Record 32 of Set 3 | sorochinsk
# Processing Record 33 of Set 3 | tura
# Processing Record 34 of Set 3 | bagaha
# Processing Record 35 of Set 3 | anabar
# City not found. Skipping...
# Processing Record 36 of Set 3 | ust-nera
# Processing Record 37 of Set 3 | ofunato
# Processing Record 38 of Set 3 | bonthe
# Processing Record 39 of Set 3 | uyuni
# Processing Record 40 of Set 3 | natal
# Processing Record 41 of Set 3 | iqaluit
# Processing Record 42 of Set 3 | broken hill
# Processing Record 43 of Set 3 | saipan
# Processing Record 44 of Set 3 | toamasina
# Processing Record 45 of Set 3 | berdigestyakh
# Processing Record 46 of Set 3 | vadso
# Processing Record 47 of Set 3 | mongo
# Processing Record 48 of Set 3 | utrik
# Processing Record 49 of Set 3 | fortuna
# Processing Record 0 of Set 4 | constantia
# Processing Record 1 of Set 4 | togur
# Processing Record 2 of Set 4 | mogocha
# Processing Record 3 of Set 4 | mejit
# Processing Record 4 of Set 4 | nar'yan-mar
# Processing Record 5 of Set 4 | acapulco de juarez
# Processing Record 6 of Set 4 | montmorillon
# Processing Record 7 of Set 4 | san antonio de pale
# Processing Record 8 of Set 4 | ivanava
# Processing Record 9 of Set 4 | wagar
# Processing Record 10 of Set 4 | georgetown
# Processing Record 11 of Set 4 | kulhudhuffushi
# Processing Record 12 of Set 4 | enewetak
# Processing Record 13 of Set 4 | marsh harbour
# Processing Record 14 of Set 4 | queenstown
# Processing Record 15 of Set 4 | phan rang-thap cham
# Processing Record 16 of Set 4 | port alfred
# Processing Record 17 of Set 4 | pont rouge
# Processing Record 18 of Set 4 | sisimiut
# Processing Record 19 of Set 4 | karkira
# Processing Record 20 of Set 4 | kapuskasing
# Processing Record 21 of Set 4 | lichinga
# Processing Record 22 of Set 4 | el granada
# Processing Record 23 of Set 4 | ulanhot
# Processing Record 24 of Set 4 | badger
# Processing Record 25 of Set 4 | vuktyl
# Processing Record 26 of Set 4 | ancud
# Processing Record 27 of Set 4 | cabo san lucas
# Processing Record 28 of Set 4 | howrah
# Processing Record 29 of Set 4 | kapa'a
# Processing Record 30 of Set 4 | talcahuano
# Processing Record 31 of Set 4 | zyryanskoye
# Processing Record 32 of Set 4 | malindi
# Processing Record 33 of Set 4 | margate
# Processing Record 34 of Set 4 | remire-montjoly
# Processing Record 35 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 36 of Set 4 | arawa
# Processing Record 37 of Set 4 | cabedelo
# Processing Record 38 of Set 4 | chongwe
# Processing Record 39 of Set 4 | chonchi
# Processing Record 40 of Set 4 | nova floresta
# Processing Record 41 of Set 4 | quellon
# Processing Record 42 of Set 4 | rudnichnyy
# Processing Record 43 of Set 4 | viitasaari
# Processing Record 44 of Set 4 | laojunmiao
# Processing Record 45 of Set 4 | holualoa
# Processing Record 46 of Set 4 | seka
# Processing Record 47 of Set 4 | kudahuvadhoo
# Processing Record 48 of Set 4 | lhuentse
# Processing Record 49 of Set 4 | amper
# Processing Record 0 of Set 5 | bardai
# Processing Record 1 of Set 5 | afaahiti
# Processing Record 2 of Set 5 | tuy hoa
# Processing Record 3 of Set 5 | tobelo
# Processing Record 4 of Set 5 | fang
# Processing Record 5 of Set 5 | stanley
# Processing Record 6 of Set 5 | pandan
# Processing Record 7 of Set 5 | braganca
# Processing Record 8 of Set 5 | ta`u
# Processing Record 9 of Set 5 | chabahar
# Processing Record 10 of Set 5 | cowra
# Processing Record 11 of Set 5 | general acha
# Processing Record 12 of Set 5 | nova sintra
# Processing Record 13 of Set 5 | katsuura
# Processing Record 14 of Set 5 | la punta
# Processing Record 15 of Set 5 | al khums
# Processing Record 16 of Set 5 | la'ie
# Processing Record 17 of Set 5 | roccella ionica
# Processing Record 18 of Set 5 | greenland
# Processing Record 19 of Set 5 | hasaki
# Processing Record 20 of Set 5 | college
# Processing Record 21 of Set 5 | udachny
# Processing Record 22 of Set 5 | sanctuary point
# Processing Record 23 of Set 5 | palapye
# Processing Record 24 of Set 5 | gobabis
# Processing Record 25 of Set 5 | george town
# Processing Record 26 of Set 5 | swindon
# Processing Record 27 of Set 5 | virginia
# Processing Record 28 of Set 5 | alesund
# Processing Record 29 of Set 5 | polyarnyy
# Processing Record 30 of Set 5 | nelson bay
# Processing Record 31 of Set 5 | cassilandia
# Processing Record 32 of Set 5 | kasempa
# Processing Record 33 of Set 5 | lyubinskiy
# Processing Record 34 of Set 5 | tadine
# Processing Record 35 of Set 5 | belebey
# Processing Record 36 of Set 5 | simmern
# Processing Record 37 of Set 5 | perushtitsa
# Processing Record 38 of Set 5 | nan
# Processing Record 39 of Set 5 | oyama
# Processing Record 40 of Set 5 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 41 of Set 5 | pakuranga
# Processing Record 42 of Set 5 | tabou
# Processing Record 43 of Set 5 | san matias
# Processing Record 44 of Set 5 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 45 of Set 5 | kati
# Processing Record 46 of Set 5 | khandyga
# Processing Record 47 of Set 5 | leava
# Processing Record 48 of Set 5 | minas de marcona
# Processing Record 49 of Set 5 | roma
# Processing Record 0 of Set 6 | hsinchu
# Processing Record 1 of Set 6 | nova vicosa
# Processing Record 2 of Set 6 | adrar
# Processing Record 3 of Set 6 | teyateyaneng
# Processing Record 4 of Set 6 | sao benedito do rio preto
# Processing Record 5 of Set 6 | al abyar
# Processing Record 6 of Set 6 | khartoum
# Processing Record 7 of Set 6 | alofi
# Processing Record 8 of Set 6 | kingscliff
# Processing Record 9 of Set 6 | ripky
# Processing Record 10 of Set 6 | sittwe
# Processing Record 11 of Set 6 | silver city
# Processing Record 12 of Set 6 | borzya
# Processing Record 13 of Set 6 | la estancia
# Processing Record 14 of Set 6 | trekhgornyy
# Processing Record 15 of Set 6 | chibougamau
# Processing Record 16 of Set 6 | iskateley
# Processing Record 17 of Set 6 | macheng
# Processing Record 18 of Set 6 | sur
# Processing Record 19 of Set 6 | bayramaly
# Processing Record 20 of Set 6 | lebedyn
# Processing Record 21 of Set 6 | governor's harbour
# City not found. Skipping...
# Processing Record 22 of Set 6 | newman
# Processing Record 23 of Set 6 | mosfellsbaer
# Processing Record 24 of Set 6 | penhalonga
# Processing Record 25 of Set 6 | coquimbo
# Processing Record 26 of Set 6 | fisterra
# Processing Record 27 of Set 6 | letlhakane
# Processing Record 28 of Set 6 | juybar
# Processing Record 29 of Set 6 | ogoja
# Processing Record 30 of Set 6 | callao
# Processing Record 31 of Set 6 | luanda
# Processing Record 32 of Set 6 | yonggang-up
# Processing Record 33 of Set 6 | wick
# Processing Record 34 of Set 6 | danilovka
# Processing Record 35 of Set 6 | kerema
# Processing Record 36 of Set 6 | zyryanovsk
# Processing Record 37 of Set 6 | bargara
# City not found. Skipping...
# Processing Record 38 of Set 6 | iwanai
# Processing Record 39 of Set 6 | kankanhalli
# Processing Record 40 of Set 6 | nyurba
# Processing Record 41 of Set 6 | northam
# Processing Record 42 of Set 6 | sabang
# Processing Record 43 of Set 6 | kupang
# Processing Record 44 of Set 6 | walvis bay
# Processing Record 45 of Set 6 | mangrol
# Processing Record 46 of Set 6 | ust'-ordynskiy
# Processing Record 47 of Set 6 | belle fourche
# Processing Record 48 of Set 6 | fort st. john
# Processing Record 49 of Set 6 | la ronge
# Processing Record 0 of Set 7 | yeppoon
# Processing Record 1 of Set 7 | fort bragg
# Processing Record 2 of Set 7 | hovd
# Processing Record 3 of Set 7 | banes
# Processing Record 4 of Set 7 | touros
# Processing Record 5 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 6 of Set 7 | weno
# Processing Record 7 of Set 7 | verkhnevilyuysk
# Processing Record 8 of Set 7 | san sebastian de la gomera
# Processing Record 9 of Set 7 | ust-kamenogorsk
# Processing Record 10 of Set 7 | thaton
# Processing Record 11 of Set 7 | new norfolk
# Processing Record 12 of Set 7 | la romana
# Processing Record 13 of Set 7 | magong
# Processing Record 14 of Set 7 | doba
# Processing Record 15 of Set 7 | nookat
# Processing Record 16 of Set 7 | nuuk
# Processing Record 17 of Set 7 | pisco
# Processing Record 18 of Set 7 | susuman
# Processing Record 19 of Set 7 | khamis mushait
# Processing Record 20 of Set 7 | moose jaw
# Processing Record 21 of Set 7 | krasnyy chikoy
# Processing Record 22 of Set 7 | codrington
# Processing Record 23 of Set 7 | minacu
# City not found. Skipping...
# Processing Record 24 of Set 7 | balaipungut
# Processing Record 25 of Set 7 | amursk
# Processing Record 26 of Set 7 | cockburn town
# Processing Record 27 of Set 7 | hammerfest
# Processing Record 28 of Set 7 | djambala
# Processing Record 29 of Set 7 | rafraf
# Processing Record 30 of Set 7 | cooma
# Processing Record 31 of Set 7 | borazjan
# Processing Record 32 of Set 7 | islamkot
# Processing Record 33 of Set 7 | ribeira brava
# Processing Record 34 of Set 7 | sao tome
# Processing Record 35 of Set 7 | east london
# Processing Record 36 of Set 7 | port hueneme
# Processing Record 37 of Set 7 | guatrache
# Processing Record 38 of Set 7 | dorogobuzh
# Processing Record 39 of Set 7 | bengkulu
# Processing Record 40 of Set 7 | dhuusamarreeb
# Processing Record 41 of Set 7 | altai
# Processing Record 42 of Set 7 | hawassa
# Processing Record 43 of Set 7 | zangguy
# City not found. Skipping...
# Processing Record 44 of Set 7 | douentza
# Processing Record 45 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 46 of Set 7 | ouellah
# City not found. Skipping...
# Processing Record 47 of Set 7 | la mira
# Processing Record 48 of Set 7 | sao pedro do sul
# Processing Record 49 of Set 7 | thunder bay
# Processing Record 0 of Set 8 | mhamid
# Processing Record 1 of Set 8 | pickering
# Processing Record 2 of Set 8 | namibe
# Processing Record 3 of Set 8 | vernon
# Processing Record 4 of Set 8 | arkhangel'sk
# Processing Record 5 of Set 8 | lebu
# Processing Record 6 of Set 8 | robertsport
# Processing Record 7 of Set 8 | saint-philippe
# Processing Record 8 of Set 8 | vorgashor
# Processing Record 9 of Set 8 | abasolo
# Processing Record 10 of Set 8 | tayu
# Processing Record 11 of Set 8 | siloam springs
# Processing Record 12 of Set 8 | daru
# Processing Record 13 of Set 8 | onguday
# Processing Record 14 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 8 | bhuj
# Processing Record 16 of Set 8 | richards bay
# Processing Record 17 of Set 8 | guixi
# Processing Record 18 of Set 8 | port lincoln
# Processing Record 19 of Set 8 | puerto baquerizo moreno
# Processing Record 20 of Set 8 | kidal
# Processing Record 21 of Set 8 | carnarvon
# Processing Record 22 of Set 8 | dindori
# Processing Record 23 of Set 8 | dangriga
# Processing Record 24 of Set 8 | n'zeto
# Processing Record 25 of Set 8 | flin flon
# Processing Record 26 of Set 8 | hayma'
# City not found. Skipping...
# Processing Record 27 of Set 8 | diamantina
# Processing Record 28 of Set 8 | leshan
# Processing Record 29 of Set 8 | santanyi
# Processing Record 30 of Set 8 | zhangatas
# Processing Record 31 of Set 8 | kamba
# Processing Record 32 of Set 8 | kupino
# Processing Record 33 of Set 8 | dongola
# Processing Record 34 of Set 8 | sayan
# Processing Record 35 of Set 8 | kostomuksha
# Processing Record 36 of Set 8 | jalapa
# Processing Record 37 of Set 8 | gadzhiyevo
# Processing Record 38 of Set 8 | tazacorte
# Processing Record 39 of Set 8 | san jose village
# City not found. Skipping...
# Processing Record 40 of Set 8 | spring creek
# Processing Record 41 of Set 8 | egilsstadir
# Processing Record 42 of Set 8 | general conesa
# Processing Record 43 of Set 8 | labrador city
# Processing Record 44 of Set 8 | dingzhou
# Processing Record 45 of Set 8 | mount pearl
# Processing Record 46 of Set 8 | suonenjoki
# Processing Record 47 of Set 8 | damoh
# Processing Record 48 of Set 8 | anshun
# Processing Record 49 of Set 8 | ternate
# Processing Record 0 of Set 9 | brockville
# Processing Record 1 of Set 9 | bonnyville
# Processing Record 2 of Set 9 | yigo village
# Processing Record 3 of Set 9 | alaghsas
# Processing Record 4 of Set 9 | ceelbuur
# Processing Record 5 of Set 9 | severo-yeniseyskiy
# Processing Record 6 of Set 9 | kralendijk
# Processing Record 7 of Set 9 | klyuchi
# Processing Record 8 of Set 9 | uturoa
# Processing Record 9 of Set 9 | floro
# Processing Record 10 of Set 9 | ilhabela
# Processing Record 11 of Set 9 | dunedin
# Processing Record 12 of Set 9 | hillsboro
# Processing Record 13 of Set 9 | kollam
# Processing Record 14 of Set 9 | nizhneudinsk
# Processing Record 15 of Set 9 | tannum sands
# Processing Record 16 of Set 9 | tofol
# Processing Record 17 of Set 9 | kill devil hills
# Processing Record 18 of Set 9 | palmer
# Processing Record 19 of Set 9 | tinana
# City not found. Skipping...
# Processing Record 20 of Set 9 | saint-pierre
# Processing Record 21 of Set 9 | princeville
# Processing Record 22 of Set 9 | mammoth lakes
# Processing Record 23 of Set 9 | kone
# Processing Record 24 of Set 9 | kujuvar
# City not found. Skipping...
# Processing Record 25 of Set 9 | vastaboland
# City not found. Skipping...
# Processing Record 26 of Set 9 | castillos
# Processing Record 27 of Set 9 | bemidji
# Processing Record 28 of Set 9 | mayqayyng
# Processing Record 29 of Set 9 | mossel bay
# Processing Record 30 of Set 9 | cable beach
# City not found. Skipping...
# Processing Record 31 of Set 9 | juan griego
# Processing Record 32 of Set 9 | christchurch
# Processing Record 33 of Set 9 | albesti
# Processing Record 34 of Set 9 | punta arenas
# Processing Record 35 of Set 9 | monticello
# Processing Record 36 of Set 9 | yatou
# Processing Record 37 of Set 9 | taksimo
# Processing Record 38 of Set 9 | cherdyn'
# Processing Record 39 of Set 9 | sinabang
# Processing Record 40 of Set 9 | fallon
# Processing Record 41 of Set 9 | minot
# Processing Record 42 of Set 9 | cueibet
# City not found. Skipping...
# Processing Record 43 of Set 9 | kandyagash
# Processing Record 44 of Set 9 | pemangkat
# Processing Record 45 of Set 9 | rosetta
# Processing Record 46 of Set 9 | yuzhno-kurilsk
# Processing Record 47 of Set 9 | prince albert
# Processing Record 48 of Set 9 | tubarjal
# Processing Record 49 of Set 9 | lazaro cardenas
# Processing Record 0 of Set 10 | kirakira
# Processing Record 1 of Set 10 | manzanares
# Processing Record 2 of Set 10 | we
# City not found. Skipping...
# Processing Record 3 of Set 10 | mar del plata
# Processing Record 4 of Set 10 | plettenberg bay
# Processing Record 5 of Set 10 | bikenibeu village
# Processing Record 6 of Set 10 | poronaysk
# Processing Record 7 of Set 10 | nemuro
# Processing Record 8 of Set 10 | mount gambier
# Processing Record 9 of Set 10 | buzuluk
# Processing Record 10 of Set 10 | linhai
# Processing Record 11 of Set 10 | vanadzor
# Processing Record 12 of Set 10 | reggane
# Processing Record 13 of Set 10 | ponta delgada
# Processing Record 14 of Set 10 | alindao
# Processing Record 15 of Set 10 | boguchany
# Processing Record 16 of Set 10 | taltal
# Processing Record 17 of Set 10 | al miqdadiyah
# Processing Record 18 of Set 10 | salida
# Processing Record 19 of Set 10 | kalabo
# Processing Record 20 of Set 10 | kita
# Processing Record 21 of Set 10 | luganville
# Processing Record 22 of Set 10 | toliara
# Processing Record 23 of Set 10 | fada
# Processing Record 24 of Set 10 | mersa matruh
# Processing Record 25 of Set 10 | vilyuchinsk
# Processing Record 26 of Set 10 | qingdao
# Processing Record 27 of Set 10 | potenza
# Processing Record 28 of Set 10 | tynda
# Processing Record 29 of Set 10 | fort mcmurray
# Processing Record 30 of Set 10 | guiuan
# Processing Record 31 of Set 10 | mananara
# Processing Record 32 of Set 10 | zag
# Processing Record 33 of Set 10 | aktau
# Processing Record 34 of Set 10 | howard springs
# Processing Record 35 of Set 10 | brookings
# Processing Record 36 of Set 10 | zykovo
# Processing Record 37 of Set 10 | necochea
# Processing Record 38 of Set 10 | port saint john's
# Processing Record 39 of Set 10 | moab
# Processing Record 40 of Set 10 | mbeya
# Processing Record 41 of Set 10 | arteche
# Processing Record 42 of Set 10 | gornozavodsk
# Processing Record 43 of Set 10 | tolanaro
# Processing Record 44 of Set 10 | keetmanshoop
# Processing Record 45 of Set 10 | colon
# Processing Record 46 of Set 10 | yanaul
# Processing Record 47 of Set 10 | abuja
# Processing Record 48 of Set 10 | san pedro pochutla
# Processing Record 49 of Set 10 | taman rajawali
# City not found. Skipping...
# Processing Record 0 of Set 11 | alice springs
# Processing Record 1 of Set 11 | cururupu
# Processing Record 2 of Set 11 | olyokminsk
# Processing Record 3 of Set 11 | ad dabbah
# Processing Record 4 of Set 11 | trincomalee
# Processing Record 5 of Set 11 | magistral'nyy
# Processing Record 6 of Set 11 | yeed
# Processing Record 7 of Set 11 | bowen
# Processing Record 8 of Set 11 | tindouf
# Processing Record 9 of Set 11 | al qadarif
# Processing Record 10 of Set 11 | kismayo
# Processing Record 11 of Set 11 | maine soroa
# Processing Record 12 of Set 11 | port macquarie
# Processing Record 13 of Set 11 | port blair
# Processing Record 14 of Set 11 | fale old settlement
# Processing Record 15 of Set 11 | sakakah
# Processing Record 16 of Set 11 | sao gabriel da cachoeira
# Processing Record 17 of Set 11 | raduzhny
# Processing Record 18 of Set 11 | akureyri
# Processing Record 19 of Set 11 | yagry
# City not found. Skipping...
# Processing Record 20 of Set 11 | sinop
# Processing Record 21 of Set 11 | beyneu
# Processing Record 22 of Set 11 | flying fish cove
# Processing Record 23 of Set 11 | abra pampa
# Processing Record 24 of Set 11 | chauk
# Processing Record 25 of Set 11 | rio grande
# Processing Record 26 of Set 11 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 27 of Set 11 | nagqu
# Processing Record 28 of Set 11 | constitucion
# Processing Record 29 of Set 11 | benguela
# Processing Record 30 of Set 11 | mengcheng chengguanzhen
# Processing Record 31 of Set 11 | tomatlan
# Processing Record 32 of Set 11 | mendi
# Processing Record 33 of Set 11 | verkhniy mamon
# Processing Record 34 of Set 11 | beihai
# Processing Record 35 of Set 11 | bel ombre
# Processing Record 36 of Set 11 | garissa
# Processing Record 37 of Set 11 | laguna
# Processing Record 38 of Set 11 | pangoa
# Processing Record 39 of Set 11 | strelka
# Processing Record 40 of Set 11 | kirandul
# City not found. Skipping...
# Processing Record 41 of Set 11 | barakani
# Processing Record 42 of Set 11 | andergrove
# Processing Record 43 of Set 11 | balikpapan
# Processing Record 44 of Set 11 | rabaul
# Processing Record 45 of Set 11 | campo do brito
# Processing Record 46 of Set 11 | tanga
# Processing Record 47 of Set 11 | znamenskoye
# Processing Record 48 of Set 11 | padam
# City not found. Skipping...
# Processing Record 49 of Set 11 | kavieng
# Processing Record 0 of Set 12 | sijunjung
# Processing Record 1 of Set 12 | korsakov
# Processing Record 2 of Set 12 | bathurst
# Processing Record 3 of Set 12 | dumra
# Processing Record 4 of Set 12 | south valley
# Processing Record 5 of Set 12 | funadhoo
# Processing Record 6 of Set 12 | hugo
# Processing Record 7 of Set 12 | codajas
# Processing Record 8 of Set 12 | prado
# Processing Record 9 of Set 12 | whakatane
# Processing Record 10 of Set 12 | sao raimundo nonato
# Processing Record 11 of Set 12 | nabire
# Processing Record 12 of Set 12 | luderitz
# Processing Record 13 of Set 12 | arinos
# Processing Record 14 of Set 12 | las tablas
# Processing Record 15 of Set 12 | jiuquan
# Processing Record 16 of Set 12 | tutoia
# Processing Record 17 of Set 12 | korop
# Processing Record 18 of Set 12 | enriquillo
# Processing Record 19 of Set 12 | ntossoni
# City not found. Skipping...
# Processing Record 20 of Set 12 | kununurra
# Processing Record 21 of Set 12 | lancut
# Processing Record 22 of Set 12 | ashland
# Processing Record 23 of Set 12 | birao
# Processing Record 24 of Set 12 | kingston
# Processing Record 25 of Set 12 | tsengel
# Processing Record 26 of Set 12 | thurles
# Processing Record 27 of Set 12 | teluknaga
# Processing Record 28 of Set 12 | berbera
# Processing Record 29 of Set 12 | tanjung pandan
# Processing Record 30 of Set 12 | keflavik
# Processing Record 31 of Set 12 | santa marta
# Processing Record 32 of Set 12 | terrace
# Processing Record 33 of Set 12 | pagar alam
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          548
# Lat           548
# Lng           548
# Max Temp      548
# Humidity      548
# Cloudiness    548
# Wind Speed    548
# Country       548
# Date          548
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  puerto ayora  -0.7393  -90.3518     21.97        86         100
# 1       vorkuta  67.5000   64.0000    -25.31       100         100
# 2         sitka  57.0531 -135.3300      5.72        93         100
# 3     adamstown -25.0660 -130.1015     21.55        73         100
# 4      bilibino  68.0546  166.4372    -25.38        99          24
#
#    Wind Speed Country        Date
# 0        2.24      EC  1731456148
# 1        1.68      RU  1731456149
# 2        1.49      US  1731456150
# 3        4.83      PN  1731456151
# 4        1.28      RU  1731456153

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        puerto ayora  -0.7393  -90.3518     21.97        86         100
# 1             vorkuta  67.5000   64.0000    -25.31       100         100
# 2               sitka  57.0531 -135.3300      5.72        93         100
# 3           adamstown -25.0660 -130.1015     21.55        73         100
# 4            bilibino  68.0546  166.4372    -25.38        99          24
#
#          Wind Speed Country        Date
# City_ID
# 0              2.24      EC  1731456148
# 1              1.68      RU  1731456149
# 2              1.49      US  1731456150
# 3              4.83      PN  1731456151
# 4              1.28      RU  1731456153

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')
# Incorporate the other graph properties
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature °C")
date=city_data_df['Date'].min()
plt.title(f"City Latitude vs. Temperature ({date})")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind='scatter', x='Lat', y='Humidity', marker='o', grid=True, facecolors='b', edgecolors='k', title=f'City Latitude vs. Humidity ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind='scatter', x='Lat', y='Cloudiness', marker='o', grid=True,facecolors='b', edgecolors='k', title=f'City Latitude vs. Cloudiness ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind='scatter', x='Lat', y='Wind Speed', marker='o', grid=True, facecolors='b', edgecolors='k', title=f'City Latitude vs. Wind Speed ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>= 0,:]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          vorkuta  67.5000   64.0000    -25.31       100         100
# 2            sitka  57.0531 -135.3300      5.72        93         100
# 4         bilibino  68.0546  166.4372    -25.38        99          24
# 6        nantucket  41.2835  -70.0995      6.06        75         100
# 8           shache  38.4167   77.2406      7.62        54          89
#
#          Wind Speed Country        Date
# City_ID
# 1              1.68      RU  1731456149
# 2              1.49      US  1731456150
# 4              1.28      RU  1731456153
# 6             14.92      US  1731456155
# 8              1.68      CN  1731456157

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<= 0,:]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             puerto ayora  -0.7393  -90.3518     21.97        86         100
# 3                adamstown -25.0660 -130.1015     21.55        73         100
# 5        sao joao da barra -21.6403  -41.0511     24.66        89          12
# 7          arraial do cabo -22.9661  -42.0278     22.98        88          40
# 10                waitangi -43.9535 -176.5597     13.79        67          15
#
#          Wind Speed Country        Date
# City_ID
# 0              2.24      EC  1731456148
# 3              4.83      PN  1731456151
# 5              5.61      BR  1731456154
# 7              5.66      BR  1731456156
# 10             4.02      NZ  1731456160

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Latitude vs. Temperature in Northern Hemisphere")

# Define a function to create Linear Regression plots
def lr_funcV2(x,y,name,vbl,hemi):
    (slope,intercept,rvalue,pvalue,stderror)=linregress(x,y)
    reg_values= x*slope + intercept
    plt.plot(x,reg_values,color='r')
    plt.title(f'Latitude vs. {vbl} - {hemi}')
    plt.xlabel('Latitude')
    plt.ylabel(vbl)
    line_eq = f'y = {(round(slope,2))}x + {(round(intercept,2))}'
    print(f'Linear equation: {line_eq}')
    plt.savefig(f"output_data/LinearRegresion_{name}.png")
    print(f'The r-value is: {rvalue}')

x = northern_hemi_df['Lat']
y = northern_hemi_df['Max Temp']
name = 'NH_LatVsMaxTemp'
vbl = 'Maximum Temperature C°'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.65x + 34.16
# The r-value is: -0.8752892896856608

# %%
# Linear regression on Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

x = southern_hemi_df['Lat']
y = southern_hemi_df['Max Temp']
name = 'SH_LatVsMaxTemp'
vbl = 'Maximum Temperature C°'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.29x + 27.58
# The r-value is: 0.6837244983096691

# %% [markdown]
# **Discussion about the linear relationship:**
# There is a negative correlation between latitude and maximum temperature.
# There is a positive correlation between latitude and maximum temperature.
# In the northern hemisphere, temperatures generally decrease as you move north while the temperatures generally increase in the southern hemisphere as you move closer to the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Humidity'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Humidity']
name = 'NH_LatVsHumidity'
vbl = 'Humidity (%)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.29x + 63.1
# The r-value is: 0.2921197226116422

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Humidity'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Humidity']
name = 'SH_LatVsHumidity'
vbl = 'Humidity (%)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.26x + 79.69
# The r-value is: 0.20908986708685579

# %% [markdown]
# **Discussion about the linear relationship:**
# There is a positive correlation between latitude and humidity on both hemispheres. There is a minor upward trend in humidity as latitude increases.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Cloudiness']
name = 'NH_LatVsCloudiness'
vbl = 'Cloudiness (%)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.57x + 33.17
# The r-value is: 0.2859840074645859

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Cloudiness']
name = 'SH_LatVsCloudiness'
vbl = 'Cloudiness (%)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.46x + 63.92
# The r-value is: 0.18370749460812347

# %% [markdown]
# **Discussion about the linear relationship:** In both hemispheres, there is a correlation between latitude and cloudiness. However, the scattered nature of the data points indicates that cloudiness is influenced by other factors not in data.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Wind Speed']
name = 'NH_LatVsWindSpeed'
vbl = 'Wind Speed (m/s)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.03x + 2.71
# The r-value is: 0.1777490408795345

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Wind Speed']
name = 'SH_LatVsWindSpeed'
vbl = 'Wind Speed (m/s)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.03x + 3.13
# The r-value is: -0.1471923205885645

# %% [markdown]
# **Discussion about the linear relationship:**
# The regression line shows a slight positive correlation between latitude and wind speed in the northern hemisphere while the regression line in the southern hemisphere shows a negative correlation between latitude and wind speed. In summary, these are minor trends and there are other major factors that are more influencial in determining wind speed variations.
